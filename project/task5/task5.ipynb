# %% [markdown]
# # Экспериментальное сравнение алгоритмов для регулярных запросов

# %% [markdown]
# ## Постановка задачи
#
# Задача работы -- исследование следующих задач достижимости:
#
# 1. Задача достижиомсти между всеми парами всех вершин данного графа.
# 2. Задача достижимости для определенного множества стартовых вершин.
#
# Вопросы, на которые необходимо ответить в ходе исследования.
#
# 1. Какое представление для матриц и векторов является оптимальным в контексте поставленных задач?
# 2. Как формат стартового множества влияет на эффективность работы алгоритмов?
